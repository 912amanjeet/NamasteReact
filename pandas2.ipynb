# %% [markdown]
# <a href="https://colab.research.google.com/github/912amanjeet/NamasteReact/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
myPizzaData=pd.read_excel("pizza_data.xlsx")

# %%
myPizzaData
# Out:
#      Order ID Restaurant Name         Location          Order Time  \
# 0      ORD001        Domino's     New York, NY 2024-01-05 18:30:00
# 1      ORD002     Papa John's  Los Angeles, CA 2024-02-14 20:00:00
# 2      ORD003  Little Caesars      Chicago, IL 2024-03-21 12:15:00
# 3      ORD004       Pizza Hut        Miami, FL 2024-04-10 19:45:00
# 4      ORD005   Marco's Pizza       Dallas, TX 2024-05-05 13:00:00
# ...       ...             ...              ...                 ...
# 999   ORD1001        Domino's  Albuquerque, NM 2026-07-03 19:00:00
# 1000  ORD1002       Pizza Hut      Atlanta, GA 2026-07-04 20:15:00
# 1001  ORD1003     Papa John's        Omaha, NE 2026-07-05 18:30:00
# 1002  ORD1004  Little Caesars   Louisville, KY 2026-07-06 19:45:00
# 1003  ORD1005   Marco's Pizza    Milwaukee, WI 2026-07-07 20:00:00
#
#            Delivery Time  Delivery Duration (min) Pizza Size    Pizza Type  \
# 0    2024-01-05 18:45:00                       15     Medium           Veg
# ...

# %%
#handling null in data

# %%
#isnull----- checks if the particular value is null or not

# %%
myPizzaData.isnull()
myPizzaData.isnull().sum()

myPizzaData.isnull().sum(axis=1)
myPizzaData.isnull().sum()/len(myPizzaData)*100
# Out:
# Order ID                        0.0
# Restaurant Name                 0.0
# Location                        0.0
# Order Time                      0.0
# Delivery Time                   0.0
# Delivery Duration (min)         0.0
# Pizza Size                      0.0
# Pizza Type                      0.0
# Toppings Count                  0.0
# Distance (km)                   0.0
# Traffic Level                   0.0
# Payment Method                  0.0
# Is Peak Hour                    0.0
# Is Weekend                      0.0
# Delivery Efficiency (min/km)    0.0
# Topping Density                 0.0
# Order Month                     0.0
# Payment Category                0.0
# Estimated Duration (min)        0.0
# Delay (min)                     0.0
# Is Delayed                      0.0
# Pizza Complexity                0.0
# Traffic Impact                  0.0
# Order Hour                      0.0
# Restaurant Avg Time             0.0
# dtype: float64

# %%
#how to handle nulls
#drop column -54%
#rows drop
#fill up null values

# %%
myPizzaData.columns
# Out:
# Index(['Order ID', 'Restaurant Name', 'Location', 'Order Time',
#        'Delivery Time', 'Delivery Duration (min)', 'Pizza Size', 'Pizza Type',
#        'Toppings Count', 'Distance (km)', 'Traffic Level', 'Payment Method',
#        'Is Peak Hour', 'Is Weekend', 'Delivery Efficiency (min/km)',
#        'Topping Density', 'Order Month', 'Payment Category',
#        'Estimated Duration (min)', 'Delay (min)', 'Is Delayed',
#        'Pizza Complexity', 'Traffic Impact', 'Order Hour',
#        'Restaurant Avg Time'],
#       dtype='object')

# %%
myPizzaData.shape
# Out:
# (1004, 25)

# %%
myPizzaData.dropna()
# Out:
#      Order ID Restaurant Name         Location          Order Time  \
# 0      ORD001        Domino's     New York, NY 2024-01-05 18:30:00
# 1      ORD002     Papa John's  Los Angeles, CA 2024-02-14 20:00:00
# 2      ORD003  Little Caesars      Chicago, IL 2024-03-21 12:15:00
# 3      ORD004       Pizza Hut        Miami, FL 2024-04-10 19:45:00
# 4      ORD005   Marco's Pizza       Dallas, TX 2024-05-05 13:00:00
# ...       ...             ...              ...                 ...
# 999   ORD1001        Domino's  Albuquerque, NM 2026-07-03 19:00:00
# 1000  ORD1002       Pizza Hut      Atlanta, GA 2026-07-04 20:15:00
# 1001  ORD1003     Papa John's        Omaha, NE 2026-07-05 18:30:00
# 1002  ORD1004  Little Caesars   Louisville, KY 2026-07-06 19:45:00
# 1003  ORD1005   Marco's Pizza    Milwaukee, WI 2026-07-07 20:00:00
#
#            Delivery Time  Delivery Duration (min) Pizza Size    Pizza Type  \
# 0    2024-01-05 18:45:00                       15     Medium           Veg
# ...

# %%
myPizzaData.dropna(subset=["Order Month","Order Time"])
# Out:
#      Order ID Restaurant Name         Location          Order Time  \
# 0      ORD001        Domino's     New York, NY 2024-01-05 18:30:00
# 1      ORD002     Papa John's  Los Angeles, CA 2024-02-14 20:00:00
# 2      ORD003  Little Caesars      Chicago, IL 2024-03-21 12:15:00
# 3      ORD004       Pizza Hut        Miami, FL 2024-04-10 19:45:00
# 4      ORD005   Marco's Pizza       Dallas, TX 2024-05-05 13:00:00
# ...       ...             ...              ...                 ...
# 999   ORD1001        Domino's  Albuquerque, NM 2026-07-03 19:00:00
# 1000  ORD1002       Pizza Hut      Atlanta, GA 2026-07-04 20:15:00
# 1001  ORD1003     Papa John's        Omaha, NE 2026-07-05 18:30:00
# 1002  ORD1004  Little Caesars   Louisville, KY 2026-07-06 19:45:00
# 1003  ORD1005   Marco's Pizza    Milwaukee, WI 2026-07-07 20:00:00
#
#            Delivery Time  Delivery Duration (min) Pizza Size    Pizza Type  \
# 0    2024-01-05 18:45:00                       15     Medium           Veg
# ...

# %%
#HASNULL
#NOTNULL

# %%
myPizzaData["Order Time"].isnull() #returns true if only that value is null
myPizzaData["Order Time"].notnull() #returns true if value is not null
myPizzaData["Order Time"].hasnans #true - if even a single element of series is null
# Out:
# False

# %%
#Duplicates

# %%
myPizzaData.duplicated().sum()
# Out:
# np.int64(0)

# %%
#drop_duplicates() drop duplicate value
#if you want to drop particular row give Parameter(keep="last")

# %%
#RENAMING OF COLUMNS
myPizzaData.rename(columns={"Location":"Area"},inplace=True)

# %%
#if you want to any column as a index use function as index value
myPizzaData.set_index("Order ID")
#myPizzaData.rename(index={0:10,1:11,2:12})
# Out:
#          Restaurant Name             Area          Order Time  \
# Order ID
# ORD001          Domino's     New York, NY 2024-01-05 18:30:00
# ORD002       Papa John's  Los Angeles, CA 2024-02-14 20:00:00
# ORD003    Little Caesars      Chicago, IL 2024-03-21 12:15:00
# ORD004         Pizza Hut        Miami, FL 2024-04-10 19:45:00
# ORD005     Marco's Pizza       Dallas, TX 2024-05-05 13:00:00
# ...                  ...              ...                 ...
# ORD1001         Domino's  Albuquerque, NM 2026-07-03 19:00:00
# ORD1002        Pizza Hut      Atlanta, GA 2026-07-04 20:15:00
# ORD1003      Papa John's        Omaha, NE 2026-07-05 18:30:00
# ORD1004   Little Caesars   Louisville, KY 2026-07-06 19:45:00
# ORD1005    Marco's Pizza    Milwaukee, WI 2026-07-07 20:00:00
#
#                Delivery Time  Delivery Duration (min) Pizza Size  \
# Order ID
# ORD001   2024-01-05 18:45:00                       15     Medium
# ORD002   2024-02-14 20:25:00                       25      Large
# ...

# %%
#reset_index() if you changed your index want to reset again

# %%
myPizzaData[["Restaurant Name","Area"]]
# Out:
#      Restaurant Name             Area
# 0           Domino's     New York, NY
# 1        Papa John's  Los Angeles, CA
# 2     Little Caesars      Chicago, IL
# 3          Pizza Hut        Miami, FL
# 4      Marco's Pizza       Dallas, TX
# ...              ...              ...
# 999         Domino's  Albuquerque, NM
# 1000       Pizza Hut      Atlanta, GA
# 1001     Papa John's        Omaha, NE
# 1002  Little Caesars   Louisville, KY
# 1003   Marco's Pizza    Milwaukee, WI
#
# [1004 rows x 2 columns]

# %%
#loc - access through lables
#iloc - index location

# %%
myPizzaData.loc[100:201,["Restaurant Name","Area"]]
# Out:
#     Restaurant Name             Area
# 100        Domino's      Seattle, WA
# 101     Papa John's       Denver, CO
# 102  Little Caesars       Boston, MA
# 103       Pizza Hut      Chicago, IL
# 104   Marco's Pizza        Miami, FL
# ..              ...              ...
# 197  Little Caesars      Houston, TX
# 198       Pizza Hut      Phoenix, AZ
# 199   Marco's Pizza      Atlanta, GA
# 200        Domino's     New York, NY
# 201     Papa John's  Los Angeles, CA
#
# [102 rows x 2 columns]

# %%
myPizzaData.loc[100:200:,"Restaurant Name":"Topping Density"]
myPizzaData.loc[100:200:2,"Restaurant Name":"Topping Density"]
# Out:
#     Restaurant Name              Area          Order Time       Delivery Time  \
# 100        Domino's       Seattle, WA 2024-04-11 18:30:00 2024-04-11 18:50:00
# 102  Little Caesars        Boston, MA 2024-04-13 18:30:00 2024-04-13 18:50:00
# 104   Marco's Pizza         Miami, FL 2024-04-15 13:00:00 2024-04-15 13:20:00
# 106     Papa John's       Phoenix, AZ 2024-04-17 20:00:00 2024-04-17 20:25:00
# 108       Pizza Hut        Dallas, TX 2024-04-19 19:45:00 2024-04-19 20:10:00
# 110        Domino's        Denver, CO 2024-04-21 18:30:00 2024-04-21 18:50:00
# 112  Little Caesars        Dallas, TX 2024-04-23 18:30:00 2024-04-23 18:50:00
# 114   Marco's Pizza       Chicago, IL 2024-04-25 13:00:00 2024-04-25 13:20:00
# 116     Papa John's        Dallas, TX 2024-04-27 20:00:00 2024-04-27 20:25:00
# 118       Pizza Hut       Phoenix, AZ 2024-04-29 19:45:00 2024-04-29 20:10:00
# 120        Domino's       Seattle, WA 2024-05-01 18:30:00 2024-05-01 18:50:00
# ...

# %%
#iloc
myPizzaData.iloc[100:201,1:6]
myPizzaData.iloc[100:201,1:7:2]
# Out:
#     Restaurant Name          Order Time  Delivery Duration (min)
# 100        Domino's 2024-04-11 18:30:00                       20
# 101     Papa John's 2024-04-12 20:15:00                       25
# 102  Little Caesars 2024-04-13 18:30:00                       20
# 103       Pizza Hut 2024-04-14 19:45:00                       25
# 104   Marco's Pizza 2024-04-15 13:00:00                       20
# ..              ...                 ...                      ...
# 196     Papa John's 2024-07-12 20:00:00                       25
# 197  Little Caesars 2024-07-13 19:15:00                       20
# 198       Pizza Hut 2024-07-14 19:45:00                       25
# 199   Marco's Pizza 2024-07-15 13:00:00                       20
# 200        Domino's 2024-07-16 18:30:00                       25
#
# [101 rows x 3 columns]

# %%
myPizzaData["Area"].unique()
# Out:
# array(['New York, NY', 'Los Angeles, CA', 'Chicago, IL', 'Miami, FL',
#        'Dallas, TX', 'San Francisco, CA', 'Houston, TX', 'Phoenix, AZ',
#        'Atlanta, GA', 'Seattle, WA', 'Denver, CO', 'Boston, MA',
#        'San Jose, CA', 'Austin, TX', 'San Diego, CA', 'Jacksonville, FL',
#        'Fort Worth, TX', 'Columbus, OH', 'Charlotte, NC',
#        'Indianapolis, IN', 'Detroit, MI', 'El Paso, TX', 'Memphis, TN',
#        'Baltimore, MD', 'Orlando, FL', 'Philadelphia, PA',
#        'San Antonio, TX', 'Washington, DC', 'Nashville, TN',
#        'Louisville, KY', 'Milwaukee, WI', 'Albuquerque, NM', 'Tucson, AZ',
#        'Fresno, CA', 'Sacramento, CA', 'Kansas City, MO',
#        'Long Beach, CA', 'Mesa, AZ', 'Omaha, NE', 'Raleigh, NC',
#        'Tulsa, OK', 'Minneapolis, MN', 'Arlington, TX', 'New Orleans, LA',
#        'Wichita, KS', 'Cleveland, OH', 'Tampa, FL', 'Bakersfield, CA',
#        'Aurora, CO', 'Anaheim, CA', 'Honolulu, HI', 'Lexington, KY',
# ...

# %%
#GROUPING
groupy=myPizzaData.groupby("Pizza Size")

# %%
groupy.groups["Little"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-4315e1cc7e6a> in <cell line: 0>()
# ----> 1 groupy.groups["Little"]
#
# KeyError: 'Little'

# %%
myPizzaData[myPizzaData["Pizza Size"]=="Large"]
# Out:
#     Order ID Restaurant Name               Area          Order Time  \
# 1     ORD002     Papa John's    Los Angeles, CA 2024-02-14 20:00:00
# 6     ORD007     Papa John's    Los Angeles, CA 2024-01-07 20:15:00
# 10    ORD011        Domino's  San Francisco, CA 2024-01-11 17:30:00
# 15    ORD016        Domino's         Denver, CO 2024-01-16 19:45:00
# 20    ORD021        Domino's          Miami, FL 2024-01-21 18:45:00
# ..       ...             ...                ...                 ...
# 979   ORD981        Domino's    Albuquerque, NM 2026-06-13 19:00:00
# 984   ORD986        Domino's    Albuquerque, NM 2026-06-18 19:15:00
# 989   ORD991        Domino's    Albuquerque, NM 2026-06-23 19:00:00
# 994   ORD996        Domino's    Albuquerque, NM 2026-06-28 19:15:00
# 999  ORD1001        Domino's    Albuquerque, NM 2026-07-03 19:00:00
#
#           Delivery Time  Delivery Duration (min) Pizza Size Pizza Type  \
# 1   2024-02-14 20:25:00                       25      Large    Non-Veg
# ...

# %%
groupy.groups["Large"]
# Out:
# Index([  1,   6,  10,  15,  20,  25,  30,  35,  40,  45,
#        ...
#        951, 956, 961, 966, 971, 979, 984, 989, 994, 999],
#       dtype='int64', length=240)

# %%
groupy.first()
groupy.last()
groupy.nth(6)
# Out:
#    Order ID Restaurant Name             Area          Order Time  \
# 17   ORD018  Little Caesars       Dallas, TX 2024-01-18 20:00:00
# 30   ORD031        Domino's  Los Angeles, CA 2024-02-01 19:45:00
# 31   ORD032     Papa John's      Phoenix, AZ 2024-02-02 18:00:00
# 33   ORD034       Pizza Hut       Dallas, TX 2024-02-04 14:15:00
#
#          Delivery Time  Delivery Duration (min) Pizza Size    Pizza Type  \
# 17 2024-01-18 20:20:00                       20     Medium       Non-Veg
# 30 2024-02-01 20:10:00                       25      Large           Veg
# 31 2024-02-02 18:25:00                       25      Small         Vegan
# 33 2024-02-04 14:35:00                       20         XL  Cheese Burst
#
#     Toppings Count  Distance (km)  ... Topping Density Order Month  \
# 17               3            3.5  ...        0.857143     January
# 30               4            4.5  ...        0.888889    February
# 31               2            2.0  ...        1.000000    February
# ...

# %%
myPizzaData
# Out:
#      Order ID Restaurant Name             Area          Order Time  \
# 0      ORD001        Domino's     New York, NY 2024-01-05 18:30:00
# 1      ORD002     Papa John's  Los Angeles, CA 2024-02-14 20:00:00
# 2      ORD003  Little Caesars      Chicago, IL 2024-03-21 12:15:00
# 3      ORD004       Pizza Hut        Miami, FL 2024-04-10 19:45:00
# 4      ORD005   Marco's Pizza       Dallas, TX 2024-05-05 13:00:00
# ...       ...             ...              ...                 ...
# 999   ORD1001        Domino's  Albuquerque, NM 2026-07-03 19:00:00
# 1000  ORD1002       Pizza Hut      Atlanta, GA 2026-07-04 20:15:00
# 1001  ORD1003     Papa John's        Omaha, NE 2026-07-05 18:30:00
# 1002  ORD1004  Little Caesars   Louisville, KY 2026-07-06 19:45:00
# 1003  ORD1005   Marco's Pizza    Milwaukee, WI 2026-07-07 20:00:00
#
#            Delivery Time  Delivery Duration (min) Pizza Size    Pizza Type  \
# 0    2024-01-05 18:45:00                       15     Medium           Veg
# ...

# %%
#total quatity of each category
myPizzaData.groupby("Pizza Size")["Toppings Count"].sum()
# Out:
# Pizza Size
# Large      953
# Medium    1188
# Small      223
# XL        1012
# Name: Toppings Count, dtype: int64

# %%
faculty=pd.read_csv("indian_faculty_dataset.csv")

# %%
spending=pd.read_csv("spending_patterns_detailed.csv")

# %%
faculty
# Out:
#        Vidwan-ID                        Name                        Position  \
# 0         556330         Ms Dixita Kagathara             Assistant Professor
# 1         556331          Mr Firoz Sherasiya             Assistant Professor
# 2         556358            Mr Bhavin Kanani             Assistant Professor
# 3         556374          Ms Vrunda Amrutiya             Assistant Professor
# 4         556357                Mr Raj Mehta             Assistant Professor
# ...          ...                         ...                             ...
# 15495     204095  Prof Shib Shankar Banerjee             Assistant Professor
# 15496     202739                Mrs Aparna R             Assistant Professor
# 15497     170536        Dr Abhishek Majumder             Associate Professor
# 15498     206814         Dr Jaya Kishor Seth  Assistant Professor (Grade-II)
# 15499     199308      Dr Rachel Reena Philip                       Principal
#
# ...

# %%
spending
# Out:
#      Customer ID               Category                 Item  Quantity  \
# 0      CUST_0159              Groceries                 Milk         1
# 1      CUST_0017      Friend Activities  Dinner with Friends         2
# 2      CUST_0094  Housing and Utilities           Water Bill         1
# 3      CUST_0162                Fitness           Yoga Class         5
# 4      CUST_0129                  Gifts              Flowers         3
# ...          ...                    ...                  ...       ...
# 9995   CUST_0072  Housing and Utilities           Water Bill         1
# 9996   CUST_0150              Groceries               Snacks         5
# 9997   CUST_0122               Shopping          Electronics         1
# 9998   CUST_0133         Transportation           Car Repair         1
# 9999   CUST_0058  Housing and Utilities             Gas Bill         1
#
#       Price Per Unit  Total Spent  Payment Method    Location Transaction Date
# ...

# %%
faculty.groupby(["Expertise","Location"])["Has Awards"].sum().reset_index().rename(columns={"Has Awards":"Counts"})
# Out:
#                     Expertise       Location  Counts
# 0                           1      Jharkhand       1
# 1                           1         Odisha       0
# 2                           1     Tamil Nadu       2
# 3                           1      Telangana       1
# 4                           1  Uttar Pradesh       1
# ...                       ...            ...     ...
# 2799                  Zoology    West Bengal      11
# 2800        applied chemsitry     Chandigarh       0
# 2801  condense Matter Physics        Gujarat       0
# 2802  language and lingustics     Tamil Nadu       2
# 2803              spectrocopy     Chandigarh       0
#
# [2804 rows x 3 columns]

# %%
spending
# Out:
#      Customer ID               Category                 Item  Quantity  \
# 0      CUST_0159              Groceries                 Milk         1
# 1      CUST_0017      Friend Activities  Dinner with Friends         2
# 2      CUST_0094  Housing and Utilities           Water Bill         1
# 3      CUST_0162                Fitness           Yoga Class         5
# 4      CUST_0129                  Gifts              Flowers         3
# ...          ...                    ...                  ...       ...
# 9995   CUST_0072  Housing and Utilities           Water Bill         1
# 9996   CUST_0150              Groceries               Snacks         5
# 9997   CUST_0122               Shopping          Electronics         1
# 9998   CUST_0133         Transportation           Car Repair         1
# 9999   CUST_0058  Housing and Utilities             Gas Bill         1
#
#       Price Per Unit  Total Spent  Payment Method    Location Transaction Date
# ...

# %%
dictionary={
    "Quantity":["sum","max","min"],
    "Customer ID":"count",
    "Total Spent":"mean"
}

# %%
spending.groupby("Category").agg(dictionary)
# Out:
#                       Quantity         Customer ID   Total Spent
#                            sum max min       count          mean
# Category
# Fitness                   2427   5   1         799    420.652703
# Food                      2355   5   1         794     68.866574
# Friend Activities         2296   5   1         748    200.856898
# Gifts                     2364   5   1         789    316.865120
# Groceries                 2410   5   1         799     21.798110
# Hobbies                   2131   5   1         739    114.308836
# Housing and Utilities      764   1   1         764   1093.444542
# Medical/Dental             770   1   1         770    382.739091
# Personal Hygiene          2331   5   1         768    312.099336
# Shopping                  2269   5   1         775  29231.644439
# Subscriptions              740   1   1         740     24.220797
# Transportation             762   1   1         762    170.129304
# ...

# %%
spending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer ID       10000 non-null  object
#  1   Category          10000 non-null  object
#  2   Item              10000 non-null  object
#  3   Quantity          10000 non-null  int64
#  4   Price Per Unit    10000 non-null  float64
#  5   Total Spent       10000 non-null  float64
#  6   Payment Method    10000 non-null  object
#  7   Location          10000 non-null  object
#  8   Transaction Date  10000 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 703.3+ KB

# %%
spending["Transaction Date"]=pd.to_datetime(spending["Transaction Date"])

# %%
spending["Transaction Date"].dt.year
# Out:
# 0       2024
# 1       2023
# 2       2023
# 3       2024
# 4       2023
#         ...
# 9995    2023
# 9996    2024
# 9997    2024
# 9998    2024
# 9999    2024
# Name: Transaction Date, Length: 10000, dtype: int32

# %%
spending[(spending["Total Spent"]>1000)&(spending["Transaction Date"].dt.year==2023)]
# Out:
#      Customer ID               Category                Item  Quantity  \
# 8      CUST_0116                 Travel        Plane Ticket         1
# 16     CUST_0065               Shopping                 Car         4
# 36     CUST_0073               Shopping                 Car         1
# 53     CUST_0042       Personal Hygiene  Skin Care Products         4
# 63     CUST_0154               Shopping                 Car         4
# ...          ...                    ...                 ...       ...
# 9898   CUST_0132                 Travel        Plane Ticket         1
# 9910   CUST_0070  Housing and Utilities                Rent         1
# 9913   CUST_0181                Fitness   Workout Equipment         5
# 9974   CUST_0168  Housing and Utilities                Rent         1
# 9980   CUST_0140  Housing and Utilities                Rent         1
#
#       Price Per Unit  Total Spent  Payment Method    Location Transaction Date
# ...

# %%
spending[spending["Transaction Date"].dt.year==2023].groupby("Customer ID")["Total Spent"].sum().reset_index()
# Out:
#     Customer ID  Total Spent
# 0     CUST_0001      5616.62
# 1     CUST_0002     19347.00
# 2     CUST_0003      2880.09
# 3     CUST_0004      4598.14
# 4     CUST_0005      8002.04
# ..          ...          ...
# 195   CUST_0196      1692.95
# 196   CUST_0197     16154.71
# 197   CUST_0198    249888.41
# 198   CUST_0199    192183.43
# 199   CUST_0200      3783.01
#
# [200 rows x 2 columns]

# %%
pd.DataFrame(spending[spending["Transaction Date"].dt.year==2024].groupby("Customer ID")["Customer ID"].count())
# Out:
#              Customer ID
# Customer ID
# CUST_0001             22
# CUST_0002             29
# CUST_0003             26
# CUST_0004             23
# CUST_0005             22
# ...                  ...
# CUST_0196             26
# CUST_0197             26
# CUST_0198             19
# CUST_0199             18
# CUST_0200             20
#
# [200 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Customer ID'].plot(kind='hist', bins=20, title='Customer ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Customer ID'].plot(kind='line', figsize=(8, 4), title='Customer ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# ...
