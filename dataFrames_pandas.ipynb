# %% [markdown]
# <a href="https://colab.research.google.com/github/912amanjeet/NamasteReact/blob/main/dataFrames_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DataFrames**

# %%
#two dimesional data frame storage
#combination of multiple series
import pandas as pd

# %%
student_data=[[100,93,95],[98,97,100],[96,98,97],[91,100,97]]

# %%
pd.DataFrame(student_data,columns=["Maths","Physics","Chemistry"],index=["Anjali","Rani","Bableen","Rumi"])
# Out:
#          Maths  Physics  Chemistry
# Anjali     100       93         95
# Rani        98       97        100
# Bableen     96       98         97
# Rumi        91      100         97
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Maths'].plot(kind='hist', bins=20, title='Maths')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Physics'].plot(kind='hist', bins=20, title='Physics')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Chemistry'].plot(kind='hist', bins=20, title='Chemistry')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
student_dict={
    "Name":["Ajay","Mohit","Pranav","Rishi","Shyam"],
    "Maths":[100,98,95,97,98],
    "Physics":[99,98,95,94,99],
    "Chemistry":[96,97,93,92,91],
}
pd.DataFrame(student_dict)
# Out:
#      Name  Maths  Physics  Chemistry
# 0    Ajay    100       99         96
# 1   Mohit     98       98         97
# 2  Pranav     95       95         93
# 3   Rishi     97       94         92
# 4   Shyam     98       99         91
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['Maths'].plot(kind='hist', bins=20, title='Maths')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Physics'].plot(kind='hist', bins=20, title='Physics')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Chemistry'].plot(kind='hist', bins=20, title='Chemistry')
# ...
